# %%
#setting up the environment
# %pip install numpy 
# %pip install pandas
# %pip install matplotlib
# %pip install scikit-learn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# ...
# Note: you may need to restart the kernel to use updated packages.
# ...
# Note: you may need to restart the kernel to use updated packages.
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
#importing libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
#splitting dataset into test and train with X features and y target

X = data[["Size"]]
y = data[["Price"]]
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size = 0.2, random_state = 33)

# %% [markdown]
# X_train, X_test, y_train, Y_test = train_test_split(X,y,test_size = 0.2, random_state = 0) is using:
# train_test_split function. this function comes from the module sklearn.model_selection in python.
# splitting arrays or matrices into random train and test subsets.
#
# input parameters are X - features, y - target variables, test_size amount of data being tested example 0.2 means 20 percent
# random_state to make sure split is same everytime the code is run
#
# output variables are X_train for training features, X_test for testing features, y_train for training target values and y_test for testing target values

# %%
model = LinearRegression() #creating the model
model.fit(X_train, y_train) #find the best fitting line #training the model
LinearRegression()
# Out:
# LinearRegression()

# %%
#creating synthetic dataset with 200 samples, houses sized range of 0 to 2.5k square feet
#generating random house sizes

np.random.seed(33)
house_sizes = np.random.randint(500, 2500, size = 200)

#generating house prices as price = 100*size + some random noise to simulate real world conditions
house_prices = 100*house_sizes + np.random.normal(0,100000, size = 200)

#creating dataframe
data = pd.DataFrame({"Size" : house_sizes, "Price" : house_prices}) 
data.head()
# Out:
#    Size          Price
# 0  1544  102302.348801
# 1   891  183753.092902
# 2  2252  258197.064759
# 3  1078  103855.967856
# 4  1158  119723.691004

# %% [markdown]
# np.random.seed(0) is used in numpy to generate random numbers. It sets the seed for the generator. Setting a seed will always give the same random numbers each time the code is run.
# np.random.randint(a,b,size=c) will generate "c" random integers between "a" and "b"
# np.random.rand(5) for example will generate 5 random numbers

# %%
#making predictions on the test set

predictions = model.predict(X_test)

# %%
#visualizing the results

plt.figure(figsize = (10,6)) #setting plot size or the canvas size

#plotting training data

#syntax : plt.scatter(x,y, **kwargs) x - data for x axis,  y - data for y axis, kwargs -keyword arguments,can be color, size, transparency, label

plt. scatter(X_train, y_train, c="blue", label ="Training Data")

#plotting testing data

plt.scatter(X_test, y_test, c ="green", label = "Testing Data")
plt.legend() #To show the label

#plotting regression line 

plt.plot(X_test, predictions, color = "red", linewidth = 2, label = "Regression Line")

#Adding labels and title

plt.title("House Price Prediction")
plt.xlabel("Size (sq ft)")
plt.ylabel("Price (dollars)")
plt.legend()
plt.grid()

#show the plot
plt.show()
